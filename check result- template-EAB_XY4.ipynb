# %%
from Core_Definition import *
import numpy as np
import os
from Auto_Algorithm import *
import csv
from Visualization import *
# from Auto_Algorithm import *
# import csv
import matplotlib.pyplot as plt

# %% [markdown]
# # read in raw data files

# %%
filenames=[]
filenames_1=[]
filenames_2=[]
filenames_3=[]
filenames_4=[]
filenames_5=[]
filenames_ordered=[]
filenames_1_ordered=[]
filenames_2_ordered=[]
filenames_3_ordered=[]
filenames_4_ordered=[]
filenames_5_ordered=[]

paf_data_1="/Volumes/funkflower/Labs/Gates/Data/2023/202312/20231222/2023-12-22 UMD__d=2/"

L1=[]
line_Idx="000"
line_num=""
p=0 #position indicator
#------------------------------------------read in raw data-------------------------------
for f in os.listdir(paf_data_1):
    if (f.find("Line")!=-1):
        n=f.find("_")
        line_Idx=f[n+6:n+9]
        for i in range(3):
            if line_Idx[i]=="0":
                p+=1
            else:
                line_num=line_Idx[p:3]
                p=0
                break
        L1.append(int(line_num))
        filenames_1.append(f)
    else:
        print (f) #print out non datafiles just for debugging 
        continue
# print (filenames_xx1)
for Idx in range (len(filenames_1)):
    for i in range (len(filenames_1)):
        if L1[i]==Idx+1:
            filenames_1_ordered.append(filenames_1[i])
            break
print (filenames_1_ordered)


paf_data_2="/Volumes/funkflower/Labs/Gates/Data/2023/202312/20231222/2023-12-22 UMD__d=4/"

L1=[]
line_Idx="000"
line_num=""
p=0 #position indicator
#------------------------------------------read in raw data-------------------------------
for f in os.listdir(paf_data_2):
    if (f.find("Line")!=-1):
        n=f.find("_")
        line_Idx=f[n+6:n+9]
        for i in range(3):
            if line_Idx[i]=="0":
                p+=1
            else:
                line_num=line_Idx[p:3]
                p=0
                break
        L1.append(int(line_num))
        filenames_2.append(f)
    else:
        print (f) #print out non datafiles just for debugging 
        continue
# print (filenames_XYXA1)
for Idx in range (len(filenames_2)):
    for i in range (len(filenames_2)):
        if L1[i]==Idx+1:
            filenames_2_ordered.append(filenames_2[i])
            break
print (filenames_2_ordered)



paf_data_3="/Volumes/funkflower/Labs/Gates/Data/2023/202312/20231222/2023-12-22 UMD__d=8/"
L1=[]
line_Idx="000"
line_num=""
p=0 #position indicator
for f in os.listdir(paf_data_3):
    if (f.find("Line")!=-1):
        n=f.find("_")
        line_Idx=f[n+6:n+9]
        for i in range(3):
            if line_Idx[i]=="0":
                p+=1
            else:
                line_num=line_Idx[p:3]
                p=0
                break
        L1.append(int(line_num))
        filenames_3.append(f)
    else:
        print (f) #print out non datafiles just for debugging 
        continue
# print (filenames_3)
# print (L1)
for Idx in range (len(filenames_3)):
    for i in range (len(filenames_3)):
        if L1[i]==Idx+1:
            filenames_3_ordered.append(filenames_3[i])
            break

print (filenames_3_ordered)



paf_data_4="/Volumes/funkflower/Labs/Gates/Data/2023/202312/20231222/2023-12-22 UMD__d=16/"
L1=[]
line_Idx="000"
line_num=""
p=0 #position indicator
for f in os.listdir(paf_data_4):
    if (f.find("Line")!=-1):
        n=f.find("_")
        line_Idx=f[n+6:n+9]
        for i in range(3):
            if line_Idx[i]=="0":
                p+=1
            else:
                line_num=line_Idx[p:3]
                p=0
                break
        L1.append(int(line_num))
        filenames_4.append(f)
    else:
        print (f) #print out non datafiles just for debugging 
        continue

for Idx in range (len(filenames_4)):
    for i in range (len(filenames_4)):
        if L1[i]==Idx+1:
            filenames_4_ordered.append(filenames_4[i])
            break
filenames_4_ordered=filenames_4
# print (paf_data_4)
print (filenames_4_ordered)



#totalline=15
paf_data_5="/Volumes/funkflower/Labs/Gates/Data/2023/202312/20231222/2023-12-22 UMD__d=32/"
paf_data=paf_data_5
L1=[]
line_Idx="000"
line_num=""
p=0 #position indicator
for f in os.listdir(paf_data):
    if (f.find("Line")!=-1):
        n=f.find("_")
        line_Idx=f[n+6:n+9]
        for i in range(3):
            if line_Idx[i]=="0":
                p+=1
            else:
                line_num=line_Idx[p:3]
                p=0
                break
        L1.append(int(line_num))
        filenames.append(f)
    else:
        print (f) #print out non datafiles just for debugging 
        continue
# print (L1)
for Idx in range (len(L1)):
    for i in range (len(L1)):
        if L1[i]==Idx+1:
            filenames_ordered.append(filenames[i])
            break
filenames_5_ordered=filenames_ordered
print (filenames_5_ordered)

paf_data_6="/Volumes/funkflower/Labs/Gates/Data/2023/202312/20231222/d=32_noXY4/"
paf_data=paf_data_6
L1=[]
filenames=[]
filenames_ordered=[]

line_Idx="000"
line_num=""
p=0 #position indicator
for f in os.listdir(paf_data):
    if (f.find("Line")!=-1):
        n=f.find("_")
        line_Idx=f[n+6:n+9]
        for i in range(3):
            if line_Idx[i]=="0":
                p+=1
            else:
                line_num=line_Idx[p:3]
                p=0
                break
        L1.append(int(line_num))
        filenames.append(f)
    else:
        print (f) #print out non datafiles just for debugging 
        continue
# print (L1)
for Idx in range (len(L1)):
    for i in range (len(L1)):
        if L1[i]==Idx+1:
            filenames_ordered.append(filenames[i])
            break
filenames_6_ordered=filenames_ordered

print (filenames_6_ordered)


paf_data_7="/Volumes/funkflower/Labs/Gates/Data/2023/202312/20231222/d=8_noXY4/"
paf_data=paf_data_7
L1=[]
filenames=[]
filenames_ordered=[]

line_Idx="000"
line_num=""
p=0 #position indicator
for f in os.listdir(paf_data):
    if (f.find("Line")!=-1):
        n=f.find("_")
        line_Idx=f[n+6:n+9]
        for i in range(3):
            if line_Idx[i]=="0":
                p+=1
            else:
                line_num=line_Idx[p:3]
                p=0
                break
        L1.append(int(line_num))
        filenames.append(f)
    else:
        print (f) #print out non datafiles just for debugging 
        continue
# print (L1)
for Idx in range (len(L1)):
    for i in range (len(L1)):
        if L1[i]==Idx+1:
            filenames_ordered.append(filenames[i])
            break
filenames_7_ordered=filenames_ordered
# print(filenames)
print (filenames_7_ordered)

paf_data_8="/Volumes/funkflower/Labs/Gates/Data/2023/202312/20231222/d=16_noXY4/"
paf_data=paf_data_8
L1=[]
filenames=[]
filenames_ordered=[]

line_Idx="000"
line_num=""
p=0 #position indicator
for f in os.listdir(paf_data):
    if (f.find("Line")!=-1):
        n=f.find("_")
        line_Idx=f[n+6:n+9]
        for i in range(3):
            if line_Idx[i]=="0":
                p+=1
            else:
                line_num=line_Idx[p:3]
                p=0
                break
        L1.append(int(line_num))
        filenames.append(f)
    else:
        print (f) #print out non datafiles just for debugging 
        continue
# print (L1)
for Idx in range (len(L1)):
    for i in range (len(L1)):
        if L1[i]==Idx+1:
            filenames_ordered.append(filenames[i])
            break
filenames_8_ordered=filenames_ordered
# print(filenames)
print (filenames_8_ordered)
# Out:
# one gate wrong sign
# []
# archive
# ['2023-12-22-190448_Line_001.txt', '2023-12-22-190521_Line_002.txt', '2023-12-22-190553_Line_003.txt']
# ['2023-12-22-202619_Line_001.txt', '2023-12-22-202701_Line_002.txt', '2023-12-22-202742_Line_003.txt']
# 1st run
# ['2023-12-22-202056_Line_001.txt', '2023-12-22-202159_Line_002.txt']
# ['2023-12-22-194133_Line_001.txt', '2023-12-22-194334_Line_002.txt']
# ['2023-12-22-194835_Line_001.txt', '2023-12-22-195029_Line_002.txt']
# ['2023-12-22-203141_Line_001.txt', '2023-12-22-203219_Line_002.txt', '2023-12-22-203257_Line_003.txt']
# ['2023-12-22-201626_Line_001.txt', '2023-12-22-201726_Line_002.txt']

# %% [markdown]
# # load circuits

# %%
c_1=[]
c_2=[]
c_3=[]
c_4=[]
c_5=[]
file=open(r"/Volumes/funkflower/Labs/Gates/AutoAlgorithms/EAB/EAB_XY4/12222023_idle_ion_as_padding/d=2.txt", 'r')
Lines= file.readlines()
count = 0
# Strips the newline character
for line in Lines:
#     print("Line{}: {}".format(count, line.strip()))
    c_1.append(line)
#     print (circuits[count])
    count += 1
print (count)
count=0


file=open(r"/Volumes/funkflower/Labs/Gates/AutoAlgorithms/EAB/EAB_XY4/12222023_idle_ion_as_padding/d=4.txt", 'r')
Lines = file.readlines()

count = 0
# Strips the newline character
for line in Lines:
#     print("Line{}: {}".format(count, line.strip()))
    c_2.append(line)
#     print (circuits[count])
    count += 1
print (count)
count=0

file=open(r"/Volumes/funkflower/Labs/Gates/AutoAlgorithms/EAB/EAB_XY4/12222023_idle_ion_as_padding/d=8.txt", 'r')
Lines = file.readlines()
count = 0
# Strips the newline character
for line in Lines:
#     print("Line{}: {}".format(count, line.strip()))
    c_3.append(line)
#     print (circuits[count])
    count += 1
print (count)
count=0

file=open(r"/Volumes/funkflower/Labs/Gates/AutoAlgorithms/EAB/EAB_XY4/12222023_idle_ion_as_padding/d=16.txt", 'r')
Lines = file.readlines()
count = 0
# Strips the newline character
for line in Lines:
#     print("Line{}: {}".format(count, line.strip()))
    c_4.append(line)
#     print (circuits[count])
    count += 1
print (count)
count=0

file=open(r"/Volumes/funkflower/Labs/Gates/AutoAlgorithms/EAB/EAB_XY4/12222023_idle_ion_as_padding/d=32.txt", 'r')
Lines = file.readlines()
count = 0
# Strips the newline character
for line in Lines:
#     print("Line{}: {}".format(count, line.strip()))
    c_5.append(line)
#     print (circuits[count])
    count += 1
print (count)
count=0

# file=open(r"/Volumes/funkflower/Labs/Gates/AutoAlgorithms/EAB/EAB_XY4/12222023_idle_ion_as_padding/d=16.txt", 'r')
# Lines = file.readlines()
# count = 0
# # Strips the newline character
# for line in Lines:
# #     print("Line{}: {}".format(count, line.strip()))
#     c_4.append(line)
# #     print (circuits[count])
#     count += 1
# print (count)
# count=0
# Out:
# 20
# 20
# 20
# 20
# 20

# %%
Set_Mapping([2,3,5,4,1])
nqubit=5;

# %% [markdown]
# # display data

# %%
# d=8 with/without XY4
a=Quantum_State(nqubit) #0506xx
a2=Quantum_State(nqubit)#0506 pg3524 pg12 xx34
a3=Quantum_State(nqubit)#0506 pg3524 xx1234
a4=Quantum_State(nqubit)#0506 pg as xx
a5=Quantum_State(nqubit)#0506 pg3524 xx1234
a6=Quantum_State(nqubit)#0506 pg3524 xx1234
a7=Quantum_State(nqubit)#0506 pg3524 xx1234
a8=Quantum_State(nqubit)#good gates WP1100
a9=Quantum_State(nqubit)#good gates WP1200
a10=Quantum_State(nqubit)#good gates WP1300
a11=Quantum_State(nqubit)#good gates WP1300 full set
a12=Quantum_State(nqubit)#good gates WP1000 full set


b_c=Quantum_Circuit(nqubit,"xx1")
b=Quantum_State(nqubit)
b2_c=Quantum_Circuit(nqubit,"xx1")
b2=Quantum_State(nqubit)
b3_c=Quantum_Circuit(nqubit,"xx1")
b3=Quantum_State(nqubit)
b4_c=Quantum_Circuit(nqubit,"xx1")
b4=Quantum_State(nqubit)
# circuit_list=[5]


for i in range (len(filenames_3_ordered)):

    a.Import(paf_data_3+filenames_3_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced=Trace_Out(a,[0,1,2,3])
    print (filenames_3_ordered[i])

    a2.Import(paf_data_7+filenames_7_ordered[i],keep_file=True)
    traced_2=Trace_Out(a2,[0,1,2,3])
    print (filenames_7_ordered[i])

    b_c.Interpret_GatesLab_Sequence(c_3[i])
    b=b_c.Simulate()
    traced_b=Trace_Out(b,[0,1,2,3])
    Display_States_Population(states=[traced_b,traced,traced_2],label=["simulation","d=8","d=8 no XY4"])

print ("trace out data qubits")
for i in range (len(filenames_3_ordered)):
    a.Import(paf_data_3+filenames_3_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced=Trace_Out(a,[0,1])
    a2.Import(paf_data_7+filenames_7_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced_a2=Trace_Out(a2,[0,1])

    print (filenames_3_ordered[i])
    print (filenames_7_ordered[i])
    b_c.Interpret_GatesLab_Sequence(c_3[i])
    b=b_c.Simulate()
    traced_b=Trace_Out(b,[0,1])
    Display_States_Population(states=[traced_b,traced,traced_a2],label=["simulation","d=8","d=8 no XY4"])

print ("trace out ancilla qubits")
for i in range (len(filenames_3_ordered)):
    a.Import(paf_data_3+filenames_3_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced=Trace_Out(a,[2,3])
    a2.Import(paf_data_7+filenames_7_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced_a2=Trace_Out(a2,[2,3])

    print (filenames_3_ordered[i])
    print (filenames_7_ordered[i])
    b_c.Interpret_GatesLab_Sequence(c_3[i])
    b=b_c.Simulate()
    traced_b=Trace_Out(b,[2,3])
    Display_States_Population(states=[traced_b,traced,traced_a2],label=["simulation","d=8","d=8 no XY4"])
# Out:
# 2023-12-22-202619_Line_001.txt
# 2023-12-22-203141_Line_001.txt
# 2023-12-22-202701_Line_002.txt
# 2023-12-22-203219_Line_002.txt
# 2023-12-22-202742_Line_003.txt
# 2023-12-22-203257_Line_003.txt
# trace out data qubits
# 2023-12-22-202619_Line_001.txt
# 2023-12-22-203141_Line_001.txt
# 2023-12-22-202701_Line_002.txt
# 2023-12-22-203219_Line_002.txt
# 2023-12-22-202742_Line_003.txt
# 2023-12-22-203257_Line_003.txt
# trace out ancilla qubits
# 2023-12-22-202619_Line_001.txt
# 2023-12-22-203141_Line_001.txt
# 2023-12-22-202701_Line_002.txt
# 2023-12-22-203219_Line_002.txt
# 2023-12-22-202742_Line_003.txt
# 2023-12-22-203257_Line_003.txt

# %%
# print(len(filenames_4_ordered))
# print(len(filenames_8_ordered))
for i in range (len(filenames_4_ordered)):

    a.Import(paf_data_4+filenames_4_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced=Trace_Out(a,[0,1,2,3])
    print (filenames_4_ordered[i])

    a2.Import(paf_data_8+filenames_8_ordered[i],keep_file=True)
    traced_2=Trace_Out(a2,[0,1,2,3])
    print (filenames_8_ordered[i])

    b_c.Interpret_GatesLab_Sequence(c_4[i])
    b=b_c.Simulate()
    traced_b=Trace_Out(b,[0,1,2,3])
    Display_States_Population(states=[traced_b,traced,traced_2],label=["simulation","d=16","d=16 no XY4"])

print ("trace out data qubits")
for i in range (len(filenames_4_ordered)):
    a.Import(paf_data_4+filenames_4_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced=Trace_Out(a,[0,1])
    a2.Import(paf_data_8+filenames_8_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced_a2=Trace_Out(a2,[0,1])

    print (filenames_4_ordered[i])
    print (filenames_8_ordered[i])
    b_c.Interpret_GatesLab_Sequence(c_4[i])
    b=b_c.Simulate()
    traced_b=Trace_Out(b,[0,1])
    Display_States_Population(states=[traced_b,traced,traced_a2],label=["simulation","d=16","d=16 no XY4"])

print ("trace out ancilla qubits")
for i in range (len(filenames_4_ordered)):
    a.Import(paf_data_4+filenames_4_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced=Trace_Out(a,[2,3])
    a2.Import(paf_data_8+filenames_8_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced_a2=Trace_Out(a2,[2,3])

    print (filenames_4_ordered[i])
    print (filenames_8_ordered[i])
    b_c.Interpret_GatesLab_Sequence(c_4[i])
    b=b_c.Simulate()
    traced_b=Trace_Out(b,[2,3])
    Display_States_Population(states=[traced_b,traced,traced_a2],label=["simulation","d=16","d=16 no XY4"])
# Out:
# 2023-12-22-202056_Line_001.txt
# 2023-12-22-201626_Line_001.txt
# 2023-12-22-202159_Line_002.txt
# 2023-12-22-201726_Line_002.txt
# trace out data qubits
# 2023-12-22-202056_Line_001.txt
# 2023-12-22-201626_Line_001.txt
# 2023-12-22-202159_Line_002.txt
# 2023-12-22-201726_Line_002.txt
# trace out ancilla qubits
# 2023-12-22-202056_Line_001.txt
# 2023-12-22-201626_Line_001.txt
# 2023-12-22-202159_Line_002.txt
# 2023-12-22-201726_Line_002.txt

# %%
# print(len(filenames_4_ordered))
# print(len(filenames_8_ordered))
for i in range (len(filenames_5_ordered)):

    a.Import(paf_data_5+filenames_5_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced=Trace_Out(a,[0,1,2,3])
    print (filenames_5_ordered[i])

    a2.Import(paf_data_6+filenames_6_ordered[i],keep_file=True)
    traced_2=Trace_Out(a2,[0,1,2,3])
    print (filenames_6_ordered[i])

    b_c.Interpret_GatesLab_Sequence(c_5[i])
    b=b_c.Simulate()
    traced_b=Trace_Out(b,[0,1,2,3])
    Display_States_Population(states=[traced_b,traced,traced_2],label=["simulation","d=32","d=32 no XY4"])

print ("trace out data qubits")
for i in range (len(filenames_5_ordered)):
    a.Import(paf_data_5+filenames_5_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced=Trace_Out(a,[0,1])
    a2.Import(paf_data_6+filenames_6_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced_a2=Trace_Out(a2,[0,1])

    print (filenames_5_ordered[i])
    print (filenames_6_ordered[i])
    b_c.Interpret_GatesLab_Sequence(c_5[i])
    b=b_c.Simulate()
    traced_b=Trace_Out(b,[0,1])
    Display_States_Population(states=[traced_b,traced,traced_a2],label=["simulation","d=32","d=32 no XY4"])

print ("trace out ancilla qubits")
for i in range (len(filenames_5_ordered)):
    a.Import(paf_data_5+filenames_5_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced=Trace_Out(a,[2,3])
    a2.Import(paf_data_6+filenames_6_ordered[i],keep_file=True) #xx12 was bad so this result look bad
    traced_a2=Trace_Out(a2,[2,3])

    print (filenames_5_ordered[i])
    print (filenames_6_ordered[i])
    b_c.Interpret_GatesLab_Sequence(c_5[i])
    b=b_c.Simulate()
    traced_b=Trace_Out(b,[2,3])
    Display_States_Population(states=[traced_b,traced,traced_a2],label=["simulation","d=32","d=32 no XY4"])
# Out:
# 2023-12-22-194133_Line_001.txt
# 2023-12-22-194835_Line_001.txt
# 2023-12-22-194334_Line_002.txt
# 2023-12-22-195029_Line_002.txt
# trace out data qubits
# 2023-12-22-194133_Line_001.txt
# 2023-12-22-194835_Line_001.txt
# 2023-12-22-194334_Line_002.txt
# 2023-12-22-195029_Line_002.txt
# trace out ancilla qubits
# 2023-12-22-194133_Line_001.txt
# 2023-12-22-194835_Line_001.txt
# 2023-12-22-194334_Line_002.txt
# 2023-12-22-195029_Line_002.txt

# %%
pauli_error={}
pauli_error[II 0.981712547094703

# %%
Label / Pauli error rates
II 0.981712547094703
XI 0.002918277139324403
YI 0.0027456191222411455
ZI 0.0030173928414432075
IX 0.0028430229231239876
XX 0.00043158698214813135
YX 0.0004356279934809859
ZX -0.00019974261549048078
IY 0.0024571703733095793
XY 2.90360207199844e-05
YY -0.00010048243099530785
ZY 0.0003400954198446021
IZ 0.0031481575854915636
XZ 4.4012366673874814e-05
YZ 0.0004255316486024979
ZZ -0.0002478524646213065
