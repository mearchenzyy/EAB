# %%
import sys
# sys.path.append(r"Y:\Users\Yingyue\Gates_Lab_Suite-master")
sys.path.append(r"/Volumes/funkflower/Users/Yingyue/Gates_Lab_Suite-master")
sys.path.append(r"/Users/yzhu/yzhu_work/gates projects")
from data_analysis import load_datafile_ordered,load_circuit_file
from Core_Definition import *
import numpy as np
import os
from Auto_Algorithm import *
import csv
from Visualization import *
# from Auto_Algorithm import *
# import csv
import matplotlib.pyplot as plt

# %%
c_1=[]
rerun=[]
path2file=r"/Volumes/funkflower/Labs/Gates/AutoAlgorithms/EAB 2025/0107/combined_short.txt"
c_1=load_circuit_file(c_1,path2file)
c_1_new=[]
for i in range (len(c_1)):
    if (c_1[i][0]==" "):
        # print (i)
        rerun.append(i)
        c_1_new.append(c_1[i][1:])
    else:
        c_1_new.append(c_1[i])
print (len(rerun))
# Out:
# 83

# %%
c_1=[]
rerun=[]
path2file=r"/Volumes/funkflower/Labs/Gates/AutoAlgorithms/EAB 2025/0107/combined_long.txt"
c_1=load_circuit_file(c_1,path2file)
for i in range (len(c_1)):
    if (c_1[i][0]==" "):
        # print (i)
        rerun.append(i)
print (len(rerun))
# Out:
# 80

# %%
cricfname="combine_short_new.txt"
with open("/Users/yzhu/yzhu_work/gates projects/EAB/circuits/circuits to combine/"+cricfname, "w") as text_file:
    for line in c_1_new:
        text_file.write(line+"\n")

# %%
for i in range(len(c_1)):
    print (c_1[i])
# Out:
# HAD4:RX+21:HAD5:RX+11:RY+42:FTXA420.2500+:RY-42:RX-22:AZ4-0.5000:RY+52:FTXA510.2500+:RY-52:RX-12:AZ5-0.5000:RX+41:AZ2+1.0000:SKAY4+0.5000:FTXA420.2500+:SKAY4-0.5000:SKAX2-0.5000:AZ4-0.5000:SKAY5+0.5000:FTXA510.2500+:SKAY5-0.5000:SKAX1-0.5000:AZ5-0.5000:HAD4:HAD5
#
#  HAD4:RX+21:HAD5:RX+11:RY+42:FTXA420.2500+:RY-42:RX-22:AZ4-0.5000:RY+52:FTXA510.2500+:RY-52:RX-12:AZ5-0.5000:AZ5+1.0000:RX+21:SKAY4+0.5000:FTXA420.2500+:SKAY4-0.5000:SKAX2-0.5000:AZ4-0.5000:SKAY5+0.5000:FTXA510.2500+:SKAY5-0.5000:SKAX1-0.5000:AZ5-0.5000:HAD4:HAD5
#
#
#
# HAD4:RX+21:HAD5:RX+11:RY+42:FTXA420.2500+:RY-42:RX-22:AZ4-0.5000:RY+52:FTXA510.2500+:RY-52:RX-12:AZ5-0.5000:RY+41:RY+51:FTXA450.2500+:RY+41:RX+51:FTXA450.2500+:RY+41:RY+42:FTXA420.2500+:RY-42:RX-22:AZ4-0.5000:RY+52:FTXA510.2500+:RY-52:RX-12:AZ5-0.5000:HAD4:HAD5
#
#  RY+42:RY+52:RY+41:AZ5+1.0000:RY-42:RY-52
#
#  RX-42:RX-52:AZ4+1.0000:RX+51:RX+42:RX+52
#
# ...
